# %%
import urllib.request

# %%
webpage = urllib.request.urlopen('https://blogs.imf.org/category/global-economy/').read()
print(webpage)
# Out:
# b'<!DOCTYPE html>\n<html class="avada-html-layout-wide" lang="en-US" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:addthis="https://www.addthis.com/help/api-spec"  prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\n<head>\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t<title>Global Economy &#8211; IMF Blog</title>\n\t\t<style type="text/css">\n\t\t</style>\n\t\t<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="IMF Blog &raquo; Feed" href="https://blogs.imf.org/feed/" />\n<link rel="alternate" type="application/rss+xml" title="IMF Blog &raquo; Comments Feed" href="https://blogs.imf.org/comments/feed/" />\n\t\t\t\t\t<link rel="shortcut icon" href="https://blogs.imf.org/wp-content/uploads/2019/01/imf_seal.ico" type="image/x-icon" />\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\t\t<link rel="alternate" type="application/rss+xml" title="IMF Blog &raquo; Global Economy Category Feed" href="https://blogs.imf.org/category/global-economy/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/blogs.imf.org\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.4.1"}};\n\t\t\t/*! This file is auto-generated */\n\t\t\t!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);\n\t\t</script>\n\t\t<style type="text/css">\nimg.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !important;\n\tmargin: 0 .07em !important;\n\tvertical-align: -0.1em !important;\n\tbackground: none !important;\n\tpadding: 0 !important;\n}\n</style>\n\t<link rel=\'stylesheet\' id=\'wp-block-library-css\'  href=\'https://blogs.imf.org/wp-includes/css/dist/block-library/style.min.css?ver=5.4.1\' type=\' ...

# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from BeautifulSoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
phase1 = BeautifulSoup(webpage)

# %%
text = phase1.get_text(strip=True)

# %%
print(text)
# Out:
# Global Economy – IMF BlogSkip to contentIMF HomepageAbout UsBloggersTwitterFacebookInstagramLinkedInYouTubeFlickrSearch for:HomeGlobal EconomyFinancial marketsGovernmentinclusive growthtechnologyEnvironmentHomeGlobal EconomyFinancial marketsGovernmentinclusive growthtechnologyEnvironmentSearch for:Chart of the WeekTracking the $9 Trillion Global Fiscal Support to Fight COVID-19IMFBlog2020-05-20T09:00:06-05:00May 20, 2020|ByBryn Battersby,W. Raphael Lam, andElif TureGovernments have put forward swift and significant emergency lifelines to protect people in response to the pandemic.(more…)Read MoreDampening the Impact of Global Financial Shocks on Emerging Market EconomiesIMFBlog2020-05-20T09:09:03-05:00May 19, 2020|ByDamiano Sandriعربي,中文,Español,Français,日本語,Português,РусскийThe COVID-19 pandemic is impacting emerging markets through an unprecedented combination of domestic and external shocks.(more…)Read MoreMaking Economies More Resilient to DownturnsIMFBlog2020-05-18T17:27:30-05:00May 18, 2020|ByJohn BluedornandWenjie Chenعربي,中文,Español,Français,日本語,Português,РусскийThe world is in the grip of the COVID-19 pandemic and the ensuingGreat Lockdownhas pushed many countries into deep recessions—worse than during the 2008–09 global financial crisis.(more…)Read MoreChart of the WeekTracking Trade During the COVID-19 PandemicIMFBlog2020-05-14T09:00:07-05:00May 14, 2020|ByDiego Cerdeiro,Andras Komaromi,Yang Liu, andMamoon SaeedWith the current fast-changing developments, policy makers need to know what is happening to the economy in real time, but they often must settle for data telling them what happened many weeks ago.(more…)Read MoreEmerging from the Great Lockdown in Asia and EuropeIMFBlog2020-05-14T10:33:40-05:00May 12, 2020|ByChangyong RheeandPoul M. Thomsenعربي,中文,Español,Français,日本語,Português,РусскийSeveral countries in Asia and Europe, where the COVID-19 outbreak appears to have peaked, are gradually reopening their economies. Without a vaccine or effective treatment, policymakers will be balancing the benefits of resuming economic activity against the potential cost of another increase in infection rates.(more…)Read MoreHow Pandemics Leave the Poor Even Farther BehindIMFBlog2020-05-19T09:13:35-05:00May 11, 2020|ByDavide Furceri,Prakash Loungani,Jonathan D. Ostryعربي,中文,Español,Français,日本語,Português,РусскийThe COVID-19 crisis is now widely seen as the greatest economic calamity since the Great Depression. In January, the IMF expected global income to grow 3 percent; it is nowforecastto fall 3 percent, much worse than during the Great Recession of 2008-09. Behind this dire statistic is an even grimmer possibility: if past pandemics are any guide, the toll on poorer and vulnerable segments of society will be several times worse. Indeed, a recentpollof top economists found that the vast majority felt the COVID-19 pandemic will worsen inequality, in part through its disproportionate impact on low-skilled workers.Our evidence supports concerns about the adverse distributional impacts of pandemics. We find that major epidemics in this century have raised income inequality and hurt employment prospects of those with only a basic education while scarcely affecting employment of people with advanced degrees.We focus on five major events—SARS (2003), H1N1 (2009), MERS (2012), Ebola (2014) and Zika (2016)—and trace out their distributional effects in the five years following each event. On average, the Gini coefficient—a commonly-used measure of inequality—has increased steadily in the aftermath of these events. Our measure of the Gini is based on net incomes, that is market incomes after taxes and transfers. Our results show that inequality increases despite the efforts of governments to redistribute incomes from the rich to the poor to mitigate the effects of pandemics. After five years, the net Gini has gone up by nearly 1.5 percent, which is a large impact given that this measure moves slowly over time.Such long-lasting effects ...

# %%
listed_text = [x for x in text.split()]
print(listed_text)
# Out:
# ['Global', 'Economy', '–', 'IMF', 'BlogSkip', 'to', 'contentIMF', 'HomepageAbout', 'UsBloggersTwitterFacebookInstagramLinkedInYouTubeFlickrSearch', 'for:HomeGlobal', 'EconomyFinancial', 'marketsGovernmentinclusive', 'growthtechnologyEnvironmentHomeGlobal', 'EconomyFinancial', 'marketsGovernmentinclusive', 'growthtechnologyEnvironmentSearch', 'for:Chart', 'of', 'the', 'WeekTracking', 'the', '$9', 'Trillion', 'Global', 'Fiscal', 'Support', 'to', 'Fight', 'COVID-19IMFBlog2020-05-20T09:00:06-05:00May', '20,', '2020|ByBryn', 'Battersby,W.', 'Raphael', 'Lam,', 'andElif', 'TureGovernments', 'have', 'put', 'forward', 'swift', 'and', 'significant', 'emergency', 'lifelines', 'to', 'protect', 'people', 'in', 'response', 'to', 'the', 'pandemic.(more…)Read', 'MoreDampening', 'the', 'Impact', 'of', 'Global', 'Financial', 'Shocks', 'on', 'Emerging', 'Market', 'EconomiesIMFBlog2020-05-20T09:09:03-05:00May', '19,', '2020|ByDamiano', 'Sandriعربي,中文,Español,Français,日本語,Português,РусскийThe', 'COVID-19', 'pandemic', 'is', 'impacting', 'emerging', 'markets', 'through', 'an', 'unprecedented', 'combination', 'of', 'domestic', 'and', 'external', 'shocks.(more…)Read', 'MoreMaking', 'Economies', 'More', 'Resilient', 'to', 'DownturnsIMFBlog2020-05-18T17:27:30-05:00May', '18,', '2020|ByJohn', 'BluedornandWenjie', 'Chenعربي,中文,Español,Français,日本語,Português,РусскийThe', 'world', 'is', 'in', 'the', 'grip', 'of', 'the', 'COVID-19', 'pandemic', 'and', 'the', 'ensuingGreat', 'Lockdownhas', 'pushed', 'many', 'countries', 'into', 'deep', 'recessions—worse', 'than', 'during', 'the', '2008–09', 'global', 'financial', 'crisis.(more…)Read', 'MoreChart', 'of', 'the', 'WeekTracking', 'Trade', 'During', 'the', 'COVID-19', 'PandemicIMFBlog2020-05-14T09:00:07-05:00May', '14,', '2020|ByDiego', 'Cerdeiro,Andras', 'Komaromi,Yang', 'Liu,', 'andMamoon', 'SaeedWith', 'the', 'current', 'fast-changing', 'developments,', 'policy', 'makers', 'need', 'to', 'know', 'what', 'is', 'happening', 'to', 'the', 'economy', 'in', 'real', 'time,', 'but', 'they', 'often', 'must', 'settle', 'for', 'data', 'telling', 'them', 'what', 'happened', 'many', 'weeks', 'ago.(more…)Read', 'MoreEmerging', 'from', 'the', 'Great', 'Lockdown', 'in', 'Asia', 'and', 'EuropeIMFBlog2020-05-14T10:33:40-05:00May', '12,', '2020|ByChangyong', 'RheeandPoul', 'M.', 'Thomsenعربي,中文,Español,Français,日本語,Português,РусскийSeveral', 'countries', 'in', 'Asia', 'and', 'Europe,', 'where', 'the', 'COVID-19', 'outbreak', 'appears', 'to', 'have', 'peaked,', 'are', 'gradually', 'reopening', 'their', 'economies.', 'Without', 'a', 'vaccine', 'or', 'effective', 'treatment,', 'policymakers', 'will', 'be', 'balancing', 'the', 'benefits', 'of', 'resuming', 'economic', 'activity', 'against', 'the', 'potential', 'cost', 'of', 'another', 'increase', 'in', 'infection', 'rates.(more…)Read', 'MoreHow', 'Pandemics', 'Leave', 'the', 'Poor', 'Even', 'Farther', 'BehindIMFBlog2020-05-19T09:13:35-05:00May', '11,', '2020|ByDavide', 'Furceri,Prakash', 'Loungani,Jonathan', 'D.', 'Ostryعربي,中文,Español,Français,日本語,Português,РусскийThe', 'COVID-19', 'crisis', 'is', 'now', 'widely', 'seen', 'as', 'the', 'greatest', 'economic', 'calamity', 'since', 'the', 'Great', 'Depression.', 'In', 'January,', 'the', 'IMF', 'expected', 'global', 'income', 'to', 'grow', '3', 'percent;', 'it', 'is', 'nowforecastto', 'fall', '3', 'percent,', 'much', 'worse', 'than', 'during', 'the', 'Great', 'Recession', 'of', '2008-09.', 'Behind', 'this', 'dire', 'statistic', 'is', 'an', 'even', 'grimmer', 'possibility:', 'if', 'past', 'pandemics', 'are', 'any', 'guide,', 'the', 'toll', 'on', 'poorer', 'and', 'vulnerable', 'segments', 'of', 'society', 'will', 'be', 'several', 'times', 'worse.', 'Indeed,', 'a', 'recentpollof', 'top', 'economists', 'found', 'that', 'the', 'vast', 'majority', 'felt', 'the', 'COVID-19', 'pandemic', 'will', 'worsen', 'inequality,', 'in', 'part', 'through', 'its', 'disproportionate', 'impact', 'on', 'low-skilled', 'workers.Our', 'evidence', 'supports', 'con ...

# %%
# !pip install nltk
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: nltk in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.5)
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (0.15.1)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (4.46.0)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk) (2020.5.14)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
unwanted_words = stopwords.words('english')
print(unwanted_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
refined_text = listed_text[:]
for item in listed_text:
    if item in unwanted_words:
        refined_text.remove(item)

# %%
print(refined_text)
# Out:
# ['Global', 'Economy', '–', 'IMF', 'BlogSkip', 'contentIMF', 'HomepageAbout', 'UsBloggersTwitterFacebookInstagramLinkedInYouTubeFlickrSearch', 'for:HomeGlobal', 'EconomyFinancial', 'marketsGovernmentinclusive', 'growthtechnologyEnvironmentHomeGlobal', 'EconomyFinancial', 'marketsGovernmentinclusive', 'growthtechnologyEnvironmentSearch', 'for:Chart', 'WeekTracking', '$9', 'Trillion', 'Global', 'Fiscal', 'Support', 'Fight', 'COVID-19IMFBlog2020-05-20T09:00:06-05:00May', '20,', '2020|ByBryn', 'Battersby,W.', 'Raphael', 'Lam,', 'andElif', 'TureGovernments', 'put', 'forward', 'swift', 'significant', 'emergency', 'lifelines', 'protect', 'people', 'response', 'pandemic.(more…)Read', 'MoreDampening', 'Impact', 'Global', 'Financial', 'Shocks', 'Emerging', 'Market', 'EconomiesIMFBlog2020-05-20T09:09:03-05:00May', '19,', '2020|ByDamiano', 'Sandriعربي,中文,Español,Français,日本語,Português,РусскийThe', 'COVID-19', 'pandemic', 'impacting', 'emerging', 'markets', 'unprecedented', 'combination', 'domestic', 'external', 'shocks.(more…)Read', 'MoreMaking', 'Economies', 'More', 'Resilient', 'DownturnsIMFBlog2020-05-18T17:27:30-05:00May', '18,', '2020|ByJohn', 'BluedornandWenjie', 'Chenعربي,中文,Español,Français,日本語,Português,РусскийThe', 'world', 'grip', 'COVID-19', 'pandemic', 'ensuingGreat', 'Lockdownhas', 'pushed', 'many', 'countries', 'deep', 'recessions—worse', '2008–09', 'global', 'financial', 'crisis.(more…)Read', 'MoreChart', 'WeekTracking', 'Trade', 'During', 'COVID-19', 'PandemicIMFBlog2020-05-14T09:00:07-05:00May', '14,', '2020|ByDiego', 'Cerdeiro,Andras', 'Komaromi,Yang', 'Liu,', 'andMamoon', 'SaeedWith', 'current', 'fast-changing', 'developments,', 'policy', 'makers', 'need', 'know', 'happening', 'economy', 'real', 'time,', 'often', 'must', 'settle', 'data', 'telling', 'happened', 'many', 'weeks', 'ago.(more…)Read', 'MoreEmerging', 'Great', 'Lockdown', 'Asia', 'EuropeIMFBlog2020-05-14T10:33:40-05:00May', '12,', '2020|ByChangyong', 'RheeandPoul', 'M.', 'Thomsenعربي,中文,Español,Français,日本語,Português,РусскийSeveral', 'countries', 'Asia', 'Europe,', 'COVID-19', 'outbreak', 'appears', 'peaked,', 'gradually', 'reopening', 'economies.', 'Without', 'vaccine', 'effective', 'treatment,', 'policymakers', 'balancing', 'benefits', 'resuming', 'economic', 'activity', 'potential', 'cost', 'another', 'increase', 'infection', 'rates.(more…)Read', 'MoreHow', 'Pandemics', 'Leave', 'Poor', 'Even', 'Farther', 'BehindIMFBlog2020-05-19T09:13:35-05:00May', '11,', '2020|ByDavide', 'Furceri,Prakash', 'Loungani,Jonathan', 'D.', 'Ostryعربي,中文,Español,Français,日本語,Português,РусскийThe', 'COVID-19', 'crisis', 'widely', 'seen', 'greatest', 'economic', 'calamity', 'since', 'Great', 'Depression.', 'In', 'January,', 'IMF', 'expected', 'global', 'income', 'grow', '3', 'percent;', 'nowforecastto', 'fall', '3', 'percent,', 'much', 'worse', 'Great', 'Recession', '2008-09.', 'Behind', 'dire', 'statistic', 'even', 'grimmer', 'possibility:', 'past', 'pandemics', 'guide,', 'toll', 'poorer', 'vulnerable', 'segments', 'society', 'several', 'times', 'worse.', 'Indeed,', 'recentpollof', 'top', 'economists', 'found', 'vast', 'majority', 'felt', 'COVID-19', 'pandemic', 'worsen', 'inequality,', 'part', 'disproportionate', 'impact', 'low-skilled', 'workers.Our', 'evidence', 'supports', 'concerns', 'adverse', 'distributional', 'impacts', 'pandemics.', 'We', 'find', 'major', 'epidemics', 'century', 'raised', 'income', 'inequality', 'hurt', 'employment', 'prospects', 'basic', 'education', 'scarcely', 'affecting', 'employment', 'people', 'advanced', 'degrees.We', 'focus', 'five', 'major', 'events—SARS', '(2003),', 'H1N1', '(2009),', 'MERS', '(2012),', 'Ebola', '(2014)', 'Zika', '(2016)—and', 'trace', 'distributional', 'effects', 'five', 'years', 'following', 'event.', 'On', 'average,', 'Gini', 'coefficient—a', 'commonly-used', 'measure', 'inequality—has', 'increased', 'steadily', 'aftermath', 'events.', 'Our', 'measure', 'Gini', 'based', 'net', 'incomes,', 'market', 'incomes', 'taxes', 'trans ...

# %%
word_freq = nltk.FreqDist(refined_text)

# %%
print(word_freq)
# Out:
# <FreqDist with 589 samples and 724 outcomes>

# %%
for word,freq in word_freq.items():
    print(str(word),':',str(freq))
# Out:
# Global : 3
# Economy : 1
# – : 1
# IMF : 7
# BlogSkip : 1
# contentIMF : 1
# HomepageAbout : 1
# UsBloggersTwitterFacebookInstagramLinkedInYouTubeFlickrSearch : 1
# for:HomeGlobal : 1
# EconomyFinancial : 2
# marketsGovernmentinclusive : 2
# growthtechnologyEnvironmentHomeGlobal : 1
# growthtechnologyEnvironmentSearch : 1
# for:Chart : 1
# WeekTracking : 2
# $9 : 1
# Trillion : 1
# Fiscal : 1
# Support : 1
# Fight : 1
# COVID-19IMFBlog2020-05-20T09:00:06-05:00May : 1
# 20, : 1
# 2020|ByBryn : 1
# Battersby,W. : 1
# Raphael : 2
# Lam, : 2
# andElif : 1
# TureGovernments : 1
# put : 1
# forward : 1
# swift : 1
# significant : 1
# emergency : 2
# lifelines : 2
# protect : 2
# people : 4
# response : 1
# pandemic.(more…)Read : 1
# MoreDampening : 1
# Impact : 1
# Financial : 1
# Shocks : 1
# Emerging : 1
# Market : 1
# EconomiesIMFBlog2020-05-20T09:09:03-05:00May : 1
# 19, : 1
# 2020|ByDamiano : 1
# Sandriعربي,中文,Español,Français,日本語,Português,РусскийThe : 1
# COVID-19 : 9
# pandemic : 7
# impacting : 1
# emerging : 1
# markets : 1
# unprecedented : 1
# combination : 1
# domestic : 1
# external : 1
# shocks.(more…)Read : 1
# MoreMaking : 1
# Economies : 1
# More : 2
# Resilient : 1
# DownturnsIMFBlog2020-05-18T17:27:30-05:00May : 1
# 18, : 1
# 2020|ByJohn : 1
# BluedornandWenjie : 1
# Chenعربي,中文,Español,Français,日本語,Português,РусскийThe : 1
# world : 1
# grip : 1
# ensuingGreat : 1
# Lockdownhas : 1
# pushed : 1
# many : 3
# countries : 3
# deep : 1
# recessions—worse : 1
# 2008–09 : 1
# global : 3
# financial : 1
# crisis.(more…)Read : 1
# MoreChart : 1
# Trade : 1
# During : 1
# PandemicIMFBlog2020-05-14T09:00:07-05:00May : 1
# 14, : 1
# 2020|ByDiego : 1
# Cerdeiro,Andras : 1
# Komaromi,Yang : 1
# Liu, : 1
# andMamoon : 1
# SaeedWith : 1
# current : 1
# fast-changing : 1
# developments, : 1
# policy : 3
